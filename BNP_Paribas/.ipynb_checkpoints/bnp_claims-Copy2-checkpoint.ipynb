# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
df_train = pd.read_csv('train.csv')

# %%
pd.set_option('display.max_columns',200)
df_train.head(10)
# Out:
#    ID  target        v1        v2   v3        v4         v5        v6  \
# 0   3       1  1.335739  8.727474    C  3.921026   7.915266  2.599278
# 1   4       1       NaN       NaN    C       NaN   9.191265       NaN
# 2   5       1  0.943877  5.310079    C  4.410969   5.326159  3.979592
# 3   6       1  0.797415  8.304757    C  4.225930  11.627438  2.097700
# 4   8       1       NaN       NaN    C       NaN        NaN       NaN
# 5   9       0       NaN       NaN    C       NaN   8.856791       NaN
# 6  12       0  0.899806  7.312995    C  3.494148   9.946200  1.926070
# 7  21       1       NaN       NaN    C       NaN        NaN       NaN
# 8  22       0  2.078651  8.462619  NaN  3.739030   5.265636  1.573033
# 9  23       1  1.144802  5.880606    C  3.244469   9.538384  2.500001
#
#          v7        v8         v9       v10        v11       v12       v13  \
# 0  3.176895  0.012941   9.999999  0.503281  16.434108  6.085711  2.866830
# 1       NaN  2.301630        NaN  1.312910        NaN  6.507647       NaN
# 2  3.928571  0.019645  12.666667  0.765864  14.756098  6.384670  2.505589
# 3  1.987549  0.171947   8.965516  6.542669  16.347483  9.646653  3.903302
# 4       NaN       NaN        NaN  1.050328        NaN  6.320087       NaN
# 5       NaN  0.359993        NaN  1.050328        NaN  6.216077       NaN
# 6  1.770427  0.066251   5.011287  2.341356  16.274510  7.711174  5.915588
# 7       NaN       NaN        NaN  1.838074        NaN  6.424482       NaN
# 8  2.303371  0.015869  11.111111  4.463894  16.050955  8.715047  2.348053
# 9  1.559405  0.412610   9.977529  2.363238  16.091401  7.417853  4.176949
#
#          v14       v15       v16       v17       v18       v19        v20  \
# 0  11.636387  1.355013  8.571429  3.670350  0.106720  0.148883  18.869283
# 1  11.636386       NaN       NaN       NaN       NaN       NaN        NaN
# 2   9.603542  1.984127  5.882353  3.170847  0.244541  0.144258  17.952332
# 3  14.094723  1.945044  5.517242  3.610789  1.224114  0.231630  18.376407
# 4  10.991098       NaN       NaN       NaN       NaN       NaN        NaN
# 5  11.916255       NaN       NaN       NaN       NaN       NaN        NaN
# 6  12.148604  1.968303  6.601941  2.873974  0.484133  0.443661  17.226675
# 7  12.793945       NaN       NaN       NaN       NaN       NaN        NaN
# 8  12.603403  1.580461  6.666667  3.052132  0.139939  0.180616  17.754603
# 9  13.790046  2.319558  5.900000  2.768652  0.812777  0.271822  18.410067
#
#         v21   v22           v23 v24       v25       v26       v27       v28  \
# 0  7.730923   XDX -1.716131e-08   C  0.139412  1.720818  3.393503  0.590122
# 1  6.763110   GUV           NaN   C  3.056144       NaN       NaN       NaN
# 2  5.245035    FQ -2.785053e-07   E  0.113997  2.244897  5.306122  0.836005
# 3  7.517125  ACUE -4.805344e-07   D  0.148843  1.308269  2.303640  8.926662
# 4  6.414567   HIT           NaN   E       NaN       NaN       NaN       NaN
# 5  7.351426   AYX           NaN   A  0.218458       NaN       NaN       NaN
# 6  6.661479   NFD  7.813019e-07   E  0.180765  1.070040  1.566147  4.393842
# 7  7.806704  AHBW           NaN   D       NaN       NaN       NaN       NaN
# 8  6.034953   GKQ -3.643173e-07   E  0.058906  1.647940  3.089888  0.759034
# 9  8.312447   PYF  3.955979e-08   C  0.509588  1.168523  1.410891  6.908275
#
#         v29  v30  v31       v32       v33        v34       v35        v36  \
# 0  8.880867    C    A  1.083033  1.010829   7.270147  8.375452  11.326592
# 1       NaN    C    A       NaN       NaN   3.615077       NaN  14.579479
# 2  7.499999  NaN    A  1.454082  1.734693   4.043864  7.959184  12.730517
# 3  8.874521    C    B  1.587644  1.666667   8.703550  8.898468  11.302795
# 4       NaN  NaN    A       NaN       NaN   6.083151       NaN        NaN
# 5       NaN  NaN    A       NaN       NaN   7.496613       NaN  15.497964
# 6  7.928015    G    A  1.619651  2.003892   3.964911  8.735408  13.967877
# 7       NaN    C    A       NaN       NaN  11.077506       NaN        NaN
# 8  8.146068  NaN  NaN  1.264045  1.348315   6.952621  8.089888  12.754314
# 9  9.059405    C    A  2.060643  2.475247   6.498729  9.603961  14.658608
#
#         v37  v38       v39        v40       v41        v42       v43  \
# 0  0.454546    0  4.012088   7.711453  7.653429  12.707581  2.015505
# 1       NaN    0       NaN  14.305766       NaN        NaN       NaN
# 2  0.259740    0  7.378964  13.077201  6.173469  12.346939  2.926830
# 3  0.433735    0  0.287322  11.523045  7.931035  12.935823  1.470878
# 4       NaN    0       NaN  10.138920       NaN        NaN       NaN
# 5       NaN    0       NaN   7.903915       NaN        NaN       NaN
# 6  0.549451    0  0.031587  14.787641  7.266536  14.445526  1.307190
# 7       NaN    0       NaN   3.034513       NaN        NaN       NaN
# 8  0.975611    0  3.169000  12.199552  7.078652  11.741573  2.038216
# 9  0.793651    0  0.075258  10.803126  8.279704  13.267328  1.238725
#
#          v44        v45       v46 v47        v48       v49       v50  \
# 0  10.498338   9.848672  0.113561   C  12.171733  8.086643  0.899420
# 1        NaN        NaN  2.449959   E        NaN       NaN  1.379210
# 2   8.897561   5.343819  0.126035   C  12.711328  6.836734  0.604504
# 3  12.708574   9.670823  0.108387   C  12.194855  8.591954  3.329176
# 4        NaN        NaN       NaN   I        NaN       NaN  1.364536
# 5        NaN        NaN  0.262632   I        NaN       NaN  1.653583
# 6  11.765638   9.406689  0.110774   C  13.256878  8.365759  0.133520
# 7        NaN        NaN       NaN   I        NaN       NaN  2.682121
# 8  10.173000   7.936837  0.085176   D  12.940907  7.921348  1.675592
# 9  10.295850  12.480398  0.343973   I  13.982603  8.954208  0.993324
#
#         v51 v52        v53       v54       v55  v56       v57       v58  \
# 0  7.277792   G  16.747968  0.037096  1.299638   DI  3.971118  0.529802
# 1       NaN   G        NaN  1.129469       NaN   DY       NaN       NaN
# 2  9.637627   F  15.102041  0.085573  0.765305   AS  4.030613  4.277456
# 3  4.780357   H  16.621695  0.139721  1.178161   BW  3.965517  1.732102
# 4       NaN   H        NaN       NaN       NaN  NaN       NaN       NaN
# 5       NaN   K        NaN  0.131278       NaN   DX       NaN       NaN
# 6  6.368555   A  16.760736  0.097693  1.721789   AS  3.677042  0.729927
# 7       NaN   C        NaN       NaN       NaN   DP       NaN       NaN
# 8  8.851832   H  16.551725  0.015391  1.179776   AF  4.382023  0.505051
# 9  6.682327   A  16.489072  0.232800  1.707922  NaN  3.811880  6.417392
#
#          v59       v60        v61  v62       v63       v64        v65 v66  \
# 0  10.890984  1.588448  15.858152    1  0.153461  6.363189  18.303925   C
# 1        NaN       NaN        NaN    2  2.544736       NaN        NaN   A
# 2   9.105481  2.151361  16.075602    1  0.123643  5.517949  16.377205   A
# 3  11.777912  1.229246  15.927390    1  0.140260  6.292979  17.011645   A
# 4        NaN       NaN        NaN    1       NaN       NaN        NaN   C
# 5        NaN       NaN        NaN    1  0.276524       NaN        NaN   A
# 6  12.858752  0.980870  15.067893    2  0.164415  5.175563  15.655942   A
# 7        NaN       NaN        NaN    2       NaN       NaN        NaN   C
# 8  10.022723  1.441947  15.555608    0  0.067720  5.406643  16.856447   B
# 9  13.204338  1.055074  13.528267    3  0.390694  4.874554  16.499231   A
#
#          v67        v68        v69        v70 v71  v72       v73 v74 v75  \
# 0   9.314079  15.231789  17.142857  11.784549   F    1  1.614988   B   D
# 1        NaN        NaN        NaN  12.053353   F    2       NaN   B   D
# 2   8.367347  11.040463   5.882353   8.460654   B    3  2.413618   B   B
# 3   9.703065  18.568129   9.425288  13.594728   F    2  2.272541   B   D
# 4        NaN        NaN        NaN        NaN   F    1       NaN   B   D
# 5        NaN        NaN        NaN  11.521160   F    1       NaN   B   D
# 6   8.929960  19.124088  11.456310  14.152569   F    2  2.519063   B   D
# 7        NaN        NaN        NaN        NaN   F    2       NaN   B   D
# 8   8.820225  15.656566  11.666666   9.727713   B    0  1.990445   B   B
# 9  10.290842  19.495653   9.200000  15.052754   F    3  2.781119   B   D
#
#         v76       v77        v78 v79       v80        v81        v82  \
# 0  2.230940  7.292418   8.571429   E  3.000000   7.528326   8.861647
# 1       NaN       NaN        NaN   D       NaN   7.277655   3.430691
# 2  1.963971  5.918368  11.764705   E  3.333334  10.194433   8.266200
# 3  2.188198  8.213602  13.448277   B  1.947261   4.797873  13.315819
# 4       NaN       NaN        NaN   C       NaN        NaN        NaN
# 5       NaN       NaN        NaN   I       NaN   7.978375   3.811356
# 6  1.709188  7.354085  12.427184   E  1.534989   6.328159   3.490951
# 7       NaN       NaN        NaN   C       NaN        NaN        NaN
# 8  1.840990  7.078652  10.000000   P  2.962964  10.253182   8.231174
# 9  1.668671  8.644803  13.099999   C  2.651686   7.017475   3.679445
#
#         v83       v84       v85       v86        v87       v88       v89  \
# 0  0.649820  1.299638  1.707317  0.866426   9.551836  3.321300  0.095678
# 1       NaN       NaN       NaN       NaN   9.848004       NaN  2.678584
# 2  1.530611  1.530613  2.429906  1.071429   8.447465  3.367346  0.111388
# 3  1.681034  1.379310  1.587045  1.242817  10.747144  1.408046  0.039051
# 4       NaN       NaN       NaN       NaN        NaN       NaN       NaN
# 5       NaN       NaN       NaN       NaN   9.618443       NaN  0.116390
# 6  1.867705  1.984436  2.591876  1.123541  10.999548  1.147860  0.075958
# 7       NaN       NaN       NaN       NaN        NaN       NaN       NaN
# 8  1.011235  1.348314  1.600000  0.926967   6.961616  2.471910  0.040216
# 9  2.431930  2.190594  2.747749  1.512996  12.324700  0.878712  0.171153
#
#         v90 v91       v92       v93       v94       v95       v96       v97  \
# 0  0.905342   A  0.442252  5.814018  3.517720  0.462019  7.436824  5.454545
# 1       NaN   B       NaN       NaN       NaN       NaN       NaN       NaN
# 2  0.811447   G  0.271480  5.156559  4.214944  0.309657  5.663265  5.974026
# 3  1.042425   B  0.763925  5.498902  3.423944  0.832518  7.375480  6.746988
# 4       NaN   G       NaN       NaN       NaN       NaN       NaN       NaN
# 5       NaN   G       NaN       NaN       NaN       NaN       NaN       NaN
# 6  1.343752   B  0.766422  5.875069  5.841754  0.863301  6.643969  6.043957
# 7       NaN   A       NaN       NaN       NaN       NaN       NaN       NaN
# 8  0.910867   C  0.585040  5.004810  3.094116  0.632525  6.741573  6.829269
# 9  1.189657   A  1.022954  5.432639  3.152513  1.158783  7.469059  7.380952
#
#          v98       v99       v100      v101      v102      v103      v104  \
# 0   8.877414  1.191337  19.470199  8.389237  2.757375  4.374296  1.574039
# 1   8.303967       NaN        NaN       NaN       NaN       NaN       NaN
# 2  11.588858  0.841837  15.491329  5.879353  3.292788  5.924457  1.668401
# 3   6.942002  1.334611  18.256352  8.507281  2.503055  4.872157  2.573664
# 4        NaN       NaN        NaN       NaN       NaN       NaN       NaN
# 5   8.970103       NaN        NaN       NaN       NaN       NaN       NaN
# 6   6.079678  1.301881  19.036496  7.492828  2.511898  6.310835  4.697276
# 7        NaN       NaN        NaN       NaN       NaN       NaN       NaN
# 8   9.823610  0.720974  19.494949  6.672091  1.780246  4.679944  1.653404
# 9   5.772735  1.179868  13.582609  7.197289  3.694347  4.389466  3.001609
#
#        v105       v106 v107      v108      v109 v110      v111 v112 v113  \
# 0  0.007294  12.579184    E  2.382692  3.930922    B  0.433213    O  NaN
# 1  1.505335        NaN    B  1.825361  4.247858    A       NaN    U    G
# 2  0.008275  11.670572    C  1.375753  1.184211    B  3.367348    S  NaN
# 3  0.113967  12.554274    B  2.230754  1.990131    B  2.643678    J  NaN
# 4       NaN        NaN    C       NaN       NaN    A       NaN    T    G
# 5  0.193530        NaN    C  1.763765  2.442616    A       NaN    D    X
# 6  0.047703  11.075756    B  2.254819  5.180922    B  2.568094    I  NaN
# 7       NaN        NaN    E       NaN       NaN    A       NaN    F    M
# 8  0.006071  11.460973    D  1.194403  1.151316    C  1.685393    L  NaN
# 9  0.278599  10.064205    E  2.240590  3.837530    A  3.972772    J    P
#
#         v114       v115      v116       v117      v118          v119  \
# 0  15.634907   2.857144  1.951220   6.592012  5.909091 -6.297423e-07
# 1  10.308044        NaN       NaN  10.595357       NaN           NaN
# 2  11.205561  12.941177  3.129253   3.478911  6.233767 -2.792745e-07
# 3  13.777666  10.574713  1.511063   4.949609  7.180722  5.655086e-01
# 4  14.097099        NaN       NaN        NaN       NaN           NaN
# 5  15.750502        NaN       NaN   8.851677       NaN           NaN
# 6   9.010082   8.543690  1.349693  12.168719  6.593406  1.532727e+00
# 7  18.705610        NaN       NaN        NaN       NaN           NaN
# 8  12.536835   8.333332  1.931034   3.419186  7.804877  5.182423e-01
# 9  13.434123  10.700001  1.270491  10.719493  8.174604  8.931283e+00
#
#        v120      v121      v122      v123      v124 v125      v126      v127  \
# 0  1.059603  0.803572  8.000000  1.989780  0.035754   AU  1.804126  3.113719
# 1       NaN       NaN       NaN       NaN  0.598896   AF       NaN       NaN
# 2  2.138728  2.238806  9.333333  2.477596  0.013452   AE  1.773709  3.922193
# 3  1.166281  1.956521  7.018256  1.812795  0.002267   CJ  1.415230  2.954381
# 4       NaN       NaN       NaN       NaN       NaN    Z       NaN       NaN
# 5       NaN       NaN       NaN       NaN  0.049861    X       NaN       NaN
# 6  0.846716  2.232558  3.476299  1.992594  0.083758   BJ  3.276100  1.623298
# 7       NaN       NaN       NaN       NaN       NaN   BY       NaN       NaN
# 8  1.414142  1.276595  8.148148  1.875560  0.018659    S  1.159637  5.582865
# 9  0.434782  2.715964  7.325843  4.896617  0.008944    E  1.344550  1.601176
#
#        v128  v129      v130      v131
# 0  2.024285     0  0.636365  2.857144
# 1  1.957825     0       NaN       NaN
# 2  1.120468     2  0.883118  1.176472
# 3  1.990847     1  1.677108  1.034483
# 4       NaN     0       NaN       NaN
# 5  1.536222     0       NaN       NaN
# 6  2.266575     0  2.263736  0.970873
# 7       NaN     0       NaN       NaN
# 8  1.105283     0  1.170731  3.333334
# 9  1.928009     0  3.174603  1.000000

# %% [raw]
# Check columns with string labels and also print number of unique labels.
#
# We will encode the class labels as integers.

# %%
for i in df_train.columns:
    if df_train[i].dtype == 'O':
        print 'Labels in column %s:' % i, len(np.unique(df_train[i]))
        class_mapping = {label:idx for idx,label in enumerate(np.unique(df_train[i]))}
        df_train[i] = df_train[i].map(class_mapping)
# Out:
# Labels in column v3: 4
# Labels in column v22: 18211
# Labels in column v24: 5
# Labels in column v30: 8
# Labels in column v31: 4
# Labels in column v47: 10
# Labels in column v52: 13
# Labels in column v56: 123
# Labels in column v66: 3
# Labels in column v71: 9
# Labels in column v74: 3
# Labels in column v75: 4
# Labels in column v79: 18
# Labels in column v91: 8
# Labels in column v107: 8
# Labels in column v110: 3
# Labels in column v112: 23
# Labels in column v113: 37
# Labels in column v125: 91
# /usr/local/lib/python2.7/dist-packages/numpy/lib/arraysetops.py:200: FutureWarning: numpy not_equal will not check object identity in the future. The comparison did not return the same result as suggested by the identity (`is`)) and will change.
#   flag = np.concatenate(([True], aux[1:] != aux[:-1]))

# %%
df_train['v22'].dtype
# Out:
# dtype('int64')

# %% [raw]
# Check number of Nans per feature column

# %%
df_train.isnull().sum()
# Out:
# ID            0
# target        0
# v1        49832
# v2        49796
# v3            0
# v4        49796
# v5        48624
# v6        49832
# v7        49832
# v8        48619
# v9        49851
# v10          84
# v11       49836
# v12          86
# v13       49832
# v14           4
# v15       49836
# v16       49895
# v17       49796
# v18       49832
# v19       49843
# v20       49840
# v21         611
# v22           0
# v23       50675
# v24           0
# v25       48619
# v26       49832
# v27       49832
# v28       49832
#           ...
# v102      51316
# v103      49832
# v104      49832
# v105      48658
# v106      49796
# v107          0
# v108      48624
# v109      48624
# v110          0
# v111      49832
# v112          0
# v113          0
# v114         30
# v115      49895
# v116      49836
# v117      48624
# v118      49843
# v119      50680
# v120      49836
# v121      49840
# v122      49851
# v123      50678
# v124      48619
# v125          0
# v126      49832
# v127      49832
# v128      48624
# v129          0
# v130      49843
# v131      49895
# dtype: int64

# %%
print 'Number of samples (rows): %1.f' % len(df_train['v1'])
# Out:
# Number of samples (rows): 114321

# %% [raw]
# Remove columns with more than some threshold NaNs

# %%
df_train_pruned = df_train.dropna(thresh = int(0.75*114321), axis=1)

# %%
len(df_train_pruned.columns)
# Out:
# 33

# %%
df_train_pruned.head()
# Out:
#    ID  target  v3       v10       v12        v14       v21    v22  v24  v30  \
# 0   3       1   3  0.503281  6.085711  11.636387  7.730923  16671    2    3
# 1   4       1   3  1.312910  6.507647  11.636386  6.763110   7734    2    3
# 2   5       1   3  0.765864  6.384670   9.603542  5.245035   7087    4    0
# 3   6       1   3  6.542669  9.646653  14.094723  7.517125   1511    3    3
# 4   8       1   3  1.050328  6.320087  10.991098  6.414567   8038    4    0
#
#    v31       v34  v38        v40  v47       v50  v52  v56  v62  v66  v71  v72  \
# 0    1  7.270147    0   7.711453    2  0.899420    7   86    1    2    4    1
# 1    1  3.615077    0  14.305766    4  1.379210    7  102    2    0    4    2
# 2    1  4.043864    0  13.077201    2  0.604504    6   18    1    0    1    3
# 3    2  8.703550    0  11.523045    2  3.329176    8   48    1    0    4    2
# 4    1  6.083151    0  10.138920    8  1.364536    8    0    1    2    4    1
#
#    v74  v75  v79  v91  v107  v110  v112  v113       v114  v125  v129
# 0    1    3    4    1     5     1    15     0  15.634907    22     0
# 1    1    3    3    2     2     0    21    18  10.308044     7     0
# 2    1    1    4    7     3     1    19     0  11.205561     6     2
# 3    1    3    1    2     2     1    10     0  13.777666    65     1
# 4    1    3    2    7     3     0    20    18  14.097099    90     0

# %%
df_train_pruned.isnull().sum()
# Out:
# ID          0
# target      0
# v3          0
# v10        84
# v12        86
# v14         4
# v21       611
# v22         0
# v24         0
# v30         0
# v31         0
# v34       111
# v38         0
# v40       111
# v47         0
# v50        86
# v52         0
# v56         0
# v62         0
# v66         0
# v71         0
# v72         0
# v74         0
# v75         0
# v79         0
# v91         0
# v107        0
# v110        0
# v112        0
# v113        0
# v114       30
# v125        0
# v129        0
# dtype: int64

# %%
X_train = df_train_pruned.iloc[:,2:].values
y_train = df_train_pruned.iloc[:,1].values
#y_train = y_train.reshape(y_train.shape[0],1)

# %%
y_train.shape
# Out:
# (114321,)

# %%
X_train.shape
# Out:
# (114321, 31)

# %% [markdown]
# ## Impute missing values

# %%
from sklearn.preprocessing import Imputer
imr = Imputer(missing_values='NaN', strategy='mean', axis=0)
imr.fit(X_train)
X_train_im = imr.transform(X_train)

# %%
X_train
# Out:
# array([[  3.        ,   0.50328147,   6.08571076, ...,  15.6349074 ,
#          22.        ,   0.        ],
#        [  3.        ,   1.31290992,   6.50764678, ...,  10.30804351,
#           7.        ,   0.        ],
#        [  3.        ,   0.76586397,   6.38467003, ...,  11.20556132,
#           6.        ,   2.        ],
#        ...,
#        [  3.        ,   2.07877492,   6.6989251 , ...,   8.89313389,
#          81.        ,   2.        ],
#        [  3.        ,   1.29102858,   6.69220436, ...,  12.38111312,
#          51.        ,   0.        ],
#        [  3.        ,   0.85339132,   6.30639645, ...,  14.63529757,
#          86.        ,   0.        ]])

# %%
X_train_im
# Out:
# array([[  3.        ,   0.50328147,   6.08571076, ...,  15.6349074 ,
#          22.        ,   0.        ],
#        [  3.        ,   1.31290992,   6.50764678, ...,  10.30804351,
#           7.        ,   0.        ],
#        [  3.        ,   0.76586397,   6.38467003, ...,  11.20556132,
#           6.        ,   2.        ],
#        ...,
#        [  3.        ,   2.07877492,   6.6989251 , ...,   8.89313389,
#          81.        ,   2.        ],
#        [  3.        ,   1.29102858,   6.69220436, ...,  12.38111312,
#          51.        ,   0.        ],
#        [  3.        ,   0.85339132,   6.30639645, ...,  14.63529757,
#          86.        ,   0.        ]])

# %%
from sklearn.preprocessing import StandardScaler
stdsc = StandardScaler()

# %%
X_train_std = stdsc.fit_transform(X_train_im)
X_train_std.shape
# Out:
# (114321, 31)

# %%
X_train_std
# Out:
# array([[ 0.18261343, -0.99017125, -0.86089917, ...,  0.78858071,
#         -0.97301635, -0.44737166],
#        [ 0.18261343, -0.40915114, -0.40432896, ..., -1.25012396,
#         -1.56343976, -0.44737166],
#        [ 0.18261343, -0.80173208, -0.53740013, ..., -0.90662471,
#         -1.60280132,  2.43755476],
#        ...,
#        [ 0.18261343,  0.14046265, -0.19734976, ..., -1.79164011,
#          1.34931571,  2.43755476],
#        [ 0.18261343, -0.42485402, -0.20462216, ..., -0.45671591,
#          0.1684689 , -0.44737166],
#        [ 0.18261343, -0.73891913, -0.62209872, ...,  0.40600866,
#          1.54612351, -0.44737166]])

# %% [markdown]
# ## Feature Selection w/ L1 Regularization

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(penalty='l1', C=0.1)
lr.fit(X_train_std, y_train)
print('Training accuracy:', lr.score(X_train_std, y_train))
# Out:
# ('Training accuracy:', 0.76638587836005634)

# %%
lr.coef_.shape
# Out:
# (1, 31)

# %%
fig = plt.figure()
ax = plt.subplot(111)

weights, params = [],[]

## Iterate over regularization paramter C
for c in np.arange(-4,6):
    lr = LogisticRegression(penalty='l1', C=10**c, random_state=0)
    lr.fit(X_train_std, y_train)
    weights.append(lr.coef_[0])
    params.append(10**c)
    
weights = np.array(weights)

# %%
for column in range(weights.shape[1]):
    plt.plot(params, weights[:,column], 
             label=df_train_pruned.columns[column+2])
    
plt.axhline(0, color='black', linestyle='--', linewidth=3)
plt.xlim([10**(-5), 10**5])
plt.ylabel('weight coefficient')
plt.xlabel('C')
plt.xscale('log')
plt.legend(loc='upper left')
ax.legend(loc='upper center', 
          bbox_to_anchor=(1.38, 1.03),
          ncol=1, fancybox=True)
# Out:
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
len(np.unique(y_train))
# Out:
# 2

# %%
lr.n_iter_.shape
# Out:
# (1,)

# %% [markdown]
# ## Feature Selection w/ random forest

# %%
y_train[y_train==1].sum()/float(len(y_train))
# Out:
# 0.76119872989214576

# %%
np.unique(y_train)
# Out:
# array([0, 1])

# %%
len(y_train[y_train==0])/float(len(y_train))
# Out:
# 0.2388012701078542

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
feat_labels = df_train_pruned.columns[2:]

# %%
forest = RandomForestClassifier(n_estimators=100,
                                random_state=0,
                                n_jobs=-1)

# %%
forest.fit(X_train_im, y_train)
importances = forest.feature_importances_

# %%
indices = np.argsort(importances)[::-1]

for f in range(X_train.shape[1]):
    print("%2d) %-*s %f" % (f + 1, 30, 
                            feat_labels[indices[f]], 
                            importances[indices[f]]))
# Out:
#  1) v50                            0.119501
#  2) v12                            0.068354
#  3) v22                            0.063082
#  4) v21                            0.062666
#  5) v114                           0.062401
#  6) v34                            0.062035
#  7) v40                            0.061195
#  8) v14                            0.058982
#  9) v10                            0.055466
# 10) v125                           0.051980
# 11) v112                           0.040176
# 12) v52                            0.038674
# 13) v56                            0.029054
# 14) v113                           0.026003
# 15) v66                            0.024733
# 16) v107                           0.022932
# 17) v91                            0.021864
# 18) v30                            0.019673
# 19) v24                            0.018830
# 20) v79                            0.016443
# 21) v47                            0.013710
# 22) v62                            0.012042
# 23) v71                            0.010313
# 24) v72                            0.010312
# 25) v110                           0.007907
# 26) v75                            0.007415
# 27) v129                           0.006205
# 28) v31                            0.005735
# 29) v38                            0.001417
# 30) v74                            0.000522
# 31) v3                             0.000376

# %%
plt.title('Feature Importances')
plt.bar(range(X_train.shape[1]), 
        importances[indices],
        color='lightblue', 
        align='center')

plt.xticks(range(X_train.shape[1]), 
           feat_labels[indices], rotation=90)
plt.xlim([-1, X_train.shape[1]])
# Out:
# (-1, 31)

# %% [markdown]
# ## Build final training set

# %% [raw]
# Let's use only features with importance >0.04

# %%
df_train_pruned.columns
# Out:
# Index([u'ID', u'target', u'v3', u'v10', u'v12', u'v14', u'v21', u'v22', u'v24',
#        u'v30', u'v31', u'v34', u'v38', u'v40', u'v47', u'v50', u'v52', u'v56',
#        u'v62', u'v66', u'v71', u'v72', u'v74', u'v75', u'v79', u'v91', u'v107',
#        u'v110', u'v112', u'v113', u'v114', u'v125', u'v129'],
#       dtype='object')

# %%
features_list = ['target','v50','v12','v21','v22',
                 'v114','v34','v10','v40','v14','v125',
                 'v112','v52']

# %%
df_train_slimmed = df_train_pruned[features_list]

# %%
df_train_slimmed.head()
# Out:
#    target       v50       v12       v21    v22       v114       v34       v10  \
# 0       1  0.899420  6.085711  7.730923  16671  15.634907  7.270147  0.503281
# 1       1  1.379210  6.507647  6.763110   7734  10.308044  3.615077  1.312910
# 2       1  0.604504  6.384670  5.245035   7087  11.205561  4.043864  0.765864
# 3       1  3.329176  9.646653  7.517125   1511  13.777666  8.703550  6.542669
# 4       1  1.364536  6.320087  6.414567   8038  14.097099  6.083151  1.050328
#
#          v40        v14  v125  v112  v52
# 0   7.711453  11.636387    22    15    7
# 1  14.305766  11.636386     7    21    7
# 2  13.077201   9.603542     6    19    6
# 3  11.523045  14.094723    65    10    8
# 4  10.138920  10.991098    90    20    8

# %% [raw]
# Now that we have a pruned data set with only the most important features and with imputed values (ie no NaNs), let's select a model.

# %% [raw]
# First, we'll re-define X_train, y_train

# %%
X_train, y_train = df_train_slimmed.iloc[:,1:], df_train_slimmed.iloc[:,0]

# %% [raw]
# Impute the new training feature set

# %%
from sklearn.preprocessing import Imputer
imr = Imputer(missing_values='NaN',strategy='mean', axis=0)
imr = imr.fit(X_train)
X_train = imr.transform(X_train)

# %%
X_train.shape
# Out:
# (114321, 12)

# %%
y_train.shape
# Out:
# (114321,)

# %%
np.unique(y_train)
# Out:
# array([0, 1], dtype=int64)

# %% [raw]
# Let's create subsamples to speed things up.

# %%
X_train_sub = X_train[:int(0.1*X_train.shape[0])]
y_train_sub = y_train[:int(0.1*X_train.shape[0])]

# %%
X_train_sub.shape
# Out:
# (11432, 12)

# %% [markdown]
# ## Logistic Regression

# %% [raw]
# Let's first standardize the features

# %%
from sklearn.preprocessing import StandardScaler

# %%
stdsc = StandardScaler()
X_train_std = stdsc.fit_transform(X_train)

# %%
X_train
# Out:
# array([[  0.89942   ,   6.08571076,   7.73092331, ...,  22.        ,
#          15.        ,   7.        ],
#        [  1.37921007,   6.50764678,   6.7631095 , ...,   7.        ,
#          21.        ,   7.        ],
#        [  0.60450408,   6.38467003,   5.24503529, ...,   6.        ,
#          19.        ,   6.        ],
#        ...,
#        [  2.41068147,   6.6989251 ,   6.57062511, ...,  81.        ,
#          18.        ,   4.        ],
#        [  0.82165655,   6.69220436,   7.73075117, ...,  51.        ,
#           1.        ,  10.        ],
#        [  1.00066097,   6.30639645,   7.49600008, ...,  86.        ,
#           1.        ,   7.        ]])

# %%
X_train_std
# Out:
# array([[-0.51789775, -0.86089917,  0.65568076, ..., -0.97301635,
#          0.89944058,  0.12854635],
#        [-0.10707805, -0.40432896, -0.24932807, ..., -1.56343976,
#          1.91542877,  0.12854635],
#        [-0.77041918, -0.53740013, -1.66888889, ..., -1.60280132,
#          1.57676604, -0.16203454],
#        ...,
#        [ 0.77611819, -0.19734976, -0.42932144, ...,  1.34931571,
#          1.40743467, -0.74319631],
#        [-0.58448262, -0.20462216,  0.65551979, ...,  0.1684689 ,
#         -1.47119851,  1.000289  ],
#        [-0.43121029, -0.62209872,  0.43600256, ...,  1.54612351,
#         -1.47119851,  0.12854635]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(penalty='l2', C=0.1, class_weight='balanced')
lr.fit(X_train_std,y_train)
print 'Training accuracy:', lr.score(X_train_std, y_train)
# Out:
# Training accuracy: 0.594335248992

# %%
lr.intercept_
# Out:
# array([ 0.17572518])

# %%
lr.coef_.shape
# Out:
# (1, 12)

# %% [raw]
# Let's look at a validation curve for this model

# %%
from sklearn.learning_curve import validation_curve

# %%
param_range = [0.001, 0.01, 0.1, 1.0, 10.0, 100.0]

# %%
train_scores, test_scores = validation_curve(estimator=lr,
                                            X=X_train_std,
                                            y=y_train,
                                            param_name='C',
                                            param_range=param_range,
                                            cv=10)

# %%
train_mean = np.mean(train_scores,axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.plot(param_range, train_mean, 
         color='blue', marker='o', 
         markersize=5, label='training accuracy')

plt.fill_between(param_range, train_mean + train_std,
                 train_mean - train_std, alpha=0.15,
                 color='blue')

plt.plot(param_range, test_mean, 
         color='green', linestyle='--', 
         marker='s', markersize=5, 
         label='validation accuracy')

plt.fill_between(param_range, 
                 test_mean + test_std,
                 test_mean - test_std, 
                 alpha=0.15, color='green')

plt.xscale('log')
plt.legend(loc='lower right')
plt.xlabel('Parameter C')
plt.ylabel('Accuracy')
plt.ylim([0.4,0.85])
# Out:
# (0.4, 0.85)

# %%
from sklearn.metrics import confusion_matrix
#lr.fit(X_train_std, y_train)
y_pred = lr.predict(X_train_std)
confmat = confusion_matrix(y_true=y_train, y_pred=y_pred)
print (confmat)

fig, ax = plt.subplots(figsize=(2.5, 2.5))
ax.matshow(confmat, cmap=plt.cm.Blues, alpha=0.3)
for i in range(confmat.shape[0]):
    for j in range(confmat.shape[1]):
        ax.text(x=j, y=i, s=confmat[i, j], va='center', ha='center')

plt.xlabel('predicted label')
plt.ylabel('true label')
# Out:
# [[19745  7555]
#  [38828 48193]]

# %% [markdown]
# ### So logistic regression isn't doing a great job. Let's try another model.

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
forest = RandomForestClassifier(n_estimators=100, 
                                random_state=0,
                                class_weight='balanced',
                                n_jobs=-1)

# %%
forest.fit(X_train_sub,y_train_sub)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
y_train_pred = forest.predict(X_train_sub)

# %%
from sklearn.metrics import accuracy_score

# %%
print 'Random Forest training accuracy %.3f' % (accuracy_score(y_train_sub,y_train_pred))
# Out:
# Random Forest training accuracy 1.000

# %% [markdown]
# ## Boosted decision tree

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
tree = DecisionTreeClassifier(criterion='entropy',
                              random_state=0,
                              max_depth=None,
                              class_weight='balanced',min_samples_leaf = 3)

ada = AdaBoostClassifier(base_estimator=tree, 
                         n_estimators=10,
                         learning_rate=0.1,
                         random_state=0)

# %%
tree = tree.fit(X_train_sub,y_train_sub)

# %%
y_train_pred = tree.predict(X_train_sub)

# %%
tree_train = accuracy_score(y_train_sub, y_train_pred)
print 'Decision training accuracy %.3f' % (tree_train)
# Out:
# Decision training accuracy 0.929

# %%
ada = ada.fit(X_train_sub, y_train_sub)

# %%
y_train_pred = ada.predict(X_train_sub)

# %%
ada_train = accuracy_score(y_train_sub, y_train_pred) 
print 'AdaBoost training accuracy %.3f' % (ada_train)
# Out:
# AdaBoost training accuracy 1.000

# %%
ada.get_params()
# Out:
# {'algorithm': 'SAMME.R',
#  'base_estimator': DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#              max_depth=None, max_features=None, max_leaf_nodes=None,
#              min_samples_leaf=3, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#              splitter='best'),
#  'base_estimator__class_weight': 'balanced',
#  'base_estimator__criterion': 'entropy',
#  'base_estimator__max_depth': None,
#  'base_estimator__max_features': None,
#  'base_estimator__max_leaf_nodes': None,
#  'base_estimator__min_samples_leaf': 3,
#  'base_estimator__min_samples_split': 2,
#  'base_estimator__min_weight_fraction_leaf': 0.0,
#  'base_estimator__presort': False,
#  'base_estimator__random_state': 0,
#  'base_estimator__splitter': 'best',
#  'learning_rate': 0.1,
#  'n_estimators': 10,
#  'random_state': 0}

# %% [markdown]
# ## Model evaluation and hyperparameter tuning

# %%
from sklearn.grid_search import GridSearchCV

# %%
params = {'base_estimator__max_depth':[1,10,None],'n_estimators':[5,10,20,50,100]}

# %%
#grid = GridSearchCV(estimator=ada, 
#                    param_grid=params,
#                    cv=10,
#                    scoring='accuracy')

# %%
#grid.fit(X_train, y_train)

# %%
import pickle

# %%
#with open('grid_search.pkl','wb') as handle:
#    pickle.dump(grid,handle)

# %%
#grid.best_estimator_

# %%
#print grid.best_score_

# %%
#print grid.best_params_

# %%
#for params, mean_score, scores in grid.grid_scores_:
#    print("%0.3f+/-%0.2f %r"
#            % (mean_score, scores.std() / 2, params))

# %%
#print('Best parameters: %s' % grid.best_params_)
#print('Accuracy: %.2f' % grid.best_score_)

# %% [raw]
# Let's see if we can reduce the variance.

# %%
tree = DecisionTreeClassifier(criterion='entropy',
                              random_state=0,
                              max_depth=10,
                              class_weight='balanced',
                              min_samples_leaf = 3)

ada = AdaBoostClassifier(base_estimator=tree, 
                         n_estimators=10,
                         learning_rate=0.1,
                         random_state=0)

tree = tree.fit(X_train_sub,y_train_sub)
y_train_pred = tree.predict(X_train_sub)
tree_train = accuracy_score(y_train_sub, y_train_pred)
print 'Decision training accuracy %.3f' % (tree_train)
ada.fit(X_train_sub, y_train_sub)
# Out:
# Decision training accuracy 0.718
# AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#             max_depth=10, max_features=None, max_leaf_nodes=None,
#             min_samples_leaf=3, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best'),
#           learning_rate=0.1, n_estimators=10, random_state=0)

# %%
y_train_pred = ada.predict(X_train_sub)
ada_train = accuracy_score(y_train_sub, y_train_pred) 
print 'AdaBoost training accuracy %.3f' % (ada_train)
# Out:
# AdaBoost training accuracy 0.887

# %%
ada.get_params()
# Out:
# {'algorithm': 'SAMME.R',
#  'base_estimator': DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#              max_depth=10, max_features=None, max_leaf_nodes=None,
#              min_samples_leaf=3, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#              splitter='best'),
#  'base_estimator__class_weight': 'balanced',
#  'base_estimator__criterion': 'entropy',
#  'base_estimator__max_depth': 10,
#  'base_estimator__max_features': None,
#  'base_estimator__max_leaf_nodes': None,
#  'base_estimator__min_samples_leaf': 3,
#  'base_estimator__min_samples_split': 2,
#  'base_estimator__min_weight_fraction_leaf': 0.0,
#  'base_estimator__presort': False,
#  'base_estimator__random_state': 0,
#  'base_estimator__splitter': 'best',
#  'learning_rate': 0.1,
#  'n_estimators': 10,
#  'random_state': 0}

# %%
from sklearn.learning_curve import validation_curve

# %%
param_range = [1,5,10,15,20]
train_scores, test_scores = validation_curve(estimator=ada,
                                             X=X_train_sub,
                                             y=y_train_sub,
                                             param_name='base_estimator__max_depth',
                                             param_range=param_range,
                                             cv=10, 
                                             verbose=True, 
                                             n_jobs=-1)
# Out:
# [Parallel(n_jobs=-1)]: Done  49 tasks       | elapsed: 12.3min
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed: 12.9min finished

# %%
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# %%
import pickle
with open('train_mean_depth.pkl','wb') as handle:
    pickle.dump(train_mean,handle)
with open('train_std_depth.pkl','wb') as handle:
    pickle.dump(train_std,handle)
with open('test_mean_depth.pkl','wb') as handle:
    pickle.dump(test_mean,handle)
with open('test_std_depth.pkl','wb') as handle:
    pickle.dump(test_std,handle)

# %%
plt.plot(param_range, train_mean, 
         color='blue', marker='o', 
         markersize=5, label='training accuracy')

plt.fill_between(param_range, train_mean + train_std,
                 train_mean - train_std, alpha=0.15,
                 color='blue')

plt.plot(param_range, test_mean, 
         color='green', linestyle='--', 
         marker='s', markersize=5, 
         label='validation accuracy')

plt.fill_between(param_range, 
                 test_mean + test_std,
                 test_mean - test_std, 
                 alpha=0.15, color='green')

plt.legend(loc='lower right')
plt.xlabel('maximum tree depth')
plt.ylabel('accuracy')

# %% [raw]
# So we see that above a max depth of 5, we are overfitting.

# %% [raw]
# Let's now try tuning n_estimators with a max_depth of 5.

# %%
tree = DecisionTreeClassifier(criterion='entropy',
                              random_state=0,
                              max_depth=5,
                              class_weight='balanced',
                              min_samples_leaf = 3)

ada = AdaBoostClassifier(base_estimator=tree, 
                         n_estimators=1,
                         learning_rate=0.1,
                         random_state=0)

tree = tree.fit(X_train_sub,y_train_sub)
y_train_pred = tree.predict(X_train_sub)
tree_train = accuracy_score(y_train_sub, y_train_pred)
print 'Decision training accuracy %.3f' % (tree_train)
ada.fit(X_train_sub, y_train_sub)
# Out:
# Decision training accuracy 0.657
# AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#             max_depth=5, max_features=None, max_leaf_nodes=None,
#             min_samples_leaf=3, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best'),
#           learning_rate=0.1, n_estimators=1, random_state=0)

# %%
from sklearn.learning_curve import validation_curve
param_range = [1,5,10,50,100,250,500,1000]
train_scores, test_scores = validation_curve(estimator=ada,
                                             X=X_train_sub,
                                             y=y_train_sub,
                                             param_name='n_estimators',
                                             param_range=param_range,
                                             cv=10, 
                                             verbose=True, 
                                             n_jobs=-1)
# Out:
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed: 20.9min finished

# %%
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.plot(param_range, train_mean, 
         color='blue', marker='o', 
         markersize=5, label='training accuracy')

plt.fill_between(param_range, train_mean + train_std,
                 train_mean - train_std, alpha=0.15,
                 color='blue')

plt.plot(param_range, test_mean, 
         color='green', linestyle='--', 
         marker='s', markersize=5, 
         label='validation accuracy')

plt.fill_between(param_range, 
                 test_mean + test_std,
                 test_mean - test_std, 
                 alpha=0.15, color='green')

plt.legend(loc='lower right')
plt.xlabel('number of trees')
plt.ylabel('accuracy')
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %% [raw]
# Based on our cross-validation study, the optimal hyperparameters are a max_depth of 5 with 10 trees.

# %% [markdown]
# ## Applying GBT to the full data set

# %%
tree = DecisionTreeClassifier(criterion='entropy',
                              random_state=0,
                              max_depth=5,
                              class_weight='balanced',
                              min_samples_leaf = 3)

ada = AdaBoostClassifier(base_estimator=tree, 
                         n_estimators=10,
                         learning_rate=0.1,
                         random_state=0)

tree = tree.fit(X_train,y_train)
y_train_pred = tree.predict(X_train)
tree_train = accuracy_score(y_train, y_train_pred)
print 'Decision training accuracy %.3f' % (tree_train)
ada.fit(X_train, y_train)
y_train_pred = ada.predict(X_train)
ada_train = accuracy_score(y_train, y_train_pred)
print 'Adaboost training accuracy %.3f' % (ada_train)
# Out:
# Decision training accuracy 0.631
# Adaboost training accuracy 0.634

# %% [markdown]
# ## Applying the GBT model on the test set

# %%
df_test = pd.read_csv('test.csv')

# %%
pd.set_option('display.max_columns',200)
df_test.head(10)
# Out:
#    ID            v1         v2 v3        v4        v5        v6        v7  \
# 0   0  1.375465e+00  11.361141  C  4.200778  6.577000  2.081784  1.784386
# 1   1           NaN        NaN  C       NaN       NaN       NaN       NaN
# 2   2 -4.903407e-07   8.201529  C  4.544371  6.550100  1.558442  2.467532
# 3   7  2.661870e+00   3.041241  C  1.657216  9.773080  2.078337  1.430855
# 4  10  1.252822e+00  11.283352  C  4.638388  8.520510  2.302484  3.510159
# 5  11  1.733601e+00   7.525109  C  3.263905  5.608608  2.356090  2.369477
# 6  13           NaN        NaN  C       NaN       NaN       NaN       NaN
# 7  14  2.027902e+00   6.947583  C  5.840414  7.944518  3.607374  2.541107
# 8  15  1.296225e+00   9.573390  C  3.387392  9.316076  2.133125  1.650447
# 9  16           NaN        NaN  C       NaN       NaN       NaN       NaN
#
#          v8         v9       v10        v11       v12       v13        v14  \
# 0  0.011094   9.523810  1.312911  16.851853  6.961173  3.107462  12.230137
# 1       NaN        NaN  1.291029        NaN  6.618289       NaN  10.760796
# 2  0.007164   7.142858  1.575492  15.142858  6.894249  1.899789  13.306189
# 3  1.252157   7.959596  1.575493  14.424357  6.856236  5.086604  10.397026
# 4  0.074263   7.612904  1.050328  15.589989  6.273627  2.500173  11.354501
# 5  0.065481   9.935483  0.656456  15.913043  6.344974  3.538897  11.268329
# 6       NaN        NaN  2.078774        NaN  6.443916       NaN   9.522445
# 7  1.870223   9.818181  0.262583  15.383177  6.052550  4.581453  10.991098
# 8  0.236811  12.050474  5.229759  15.889070  9.540419  3.774434  14.775679
# 9       NaN        NaN  1.050329        NaN  6.210270       NaN  11.636386
#
#         v15       v16       v17       v18       v19        v20       v21  \
# 0  1.773050  2.857142  3.493816  0.096826  0.225481  17.910227  7.437806
# 1       NaN       NaN       NaN       NaN       NaN        NaN  5.895192
# 2  1.302083  3.333334  3.177414  0.070676  0.172391  17.537549  8.253452
# 3  2.803497  7.302904  1.121984  0.608524  0.476554  15.285588  5.539484
# 4  1.353503  3.018868  4.974031  0.530779  0.148821  18.669490  6.741530
# 5  1.413043  6.434783  2.370286  0.457983  0.214822  17.433422  7.210579
# 6       NaN       NaN       NaN       NaN       NaN        NaN  4.090771
# 7  2.356522  6.111111  4.945421  0.807124  0.195463  18.411066  7.930243
# 8  3.207964  3.505154  3.125759  0.882042  0.245859  18.232834  8.439870
# 9       NaN       NaN       NaN       NaN       NaN        NaN  6.985110
#
#     v22           v23 v24       v25       v26       v27       v28       v29  \
# 0  AFPB  9.558310e-07   E  0.069180  0.954152  4.386616  0.573017  6.988848
# 1   FOG           NaN   D       NaN       NaN       NaN       NaN       NaN
# 2   HXZ -2.137218e-07   B  0.059620  2.857142  2.207792  0.327134  8.311689
# 3  AGMU  5.863396e-07   E  1.779993  1.406875  1.350919  5.347444  6.474820
# 4   AWW -2.725031e-07   E  0.158719  2.586531  3.261852  3.786615  8.860045
# 5   PMR -2.709114e-08   D  0.074814  1.570727  2.530121  3.192218  7.697456
# 6   AMZ           NaN   E       NaN       NaN       NaN       NaN       NaN
# 7  AFAI -3.796670e-08   C  1.557947  2.046172  2.541107  4.289074  9.955157
# 8   EXC -6.054696e-07   E  0.213822  0.870637  2.553523  5.490699  8.797198
# 9   WZG           NaN   D       NaN       NaN       NaN       NaN       NaN
#
#    v30 v31       v32       v33       v34       v35        v36           v37  \
# 0  NaN   A  1.115242  2.081784  5.228503  8.178438  12.183225  8.333339e-01
# 1    A   A       NaN       NaN  8.387431       NaN        NaN           NaN
# 2    C   A  0.974026  1.558442  7.958990  8.311689  12.195123 -5.249334e-07
# 3    E   A  2.362111  3.852918  6.223849  6.634692  13.741929  2.011174e+00
# 4    C   A  0.998871  1.196388  5.476858  7.742663  10.814992  3.858511e-01
# 5    C   A  1.546185  3.078982  2.915391  8.540829  12.623439  7.909610e-01
# 6    C   A       NaN       NaN  7.809384       NaN        NaN           NaN
# 7    E   A  2.017938  1.434977  1.857987  8.789237  15.670123  8.627449e-01
# 8    C   B  2.230441  1.510316  5.816583  8.812768  14.836414  8.490566e-01
# 9  NaN   A       NaN       NaN  9.209334       NaN        NaN           NaN
#
#    v38           v39        v40       v41        v42       v43        v44  \
# 0    0  2.842768e+00  11.754576  6.765800  10.855019  1.296297  10.613377
# 1    4           NaN   6.737574       NaN        NaN       NaN        NaN
# 2    0  6.707352e+00   7.701325  6.883118  12.077923  3.428570  10.215687
# 3    0  8.248888e-07  10.444974  6.059153  13.189448  1.826832   7.635934
# 4    0  4.897771e-01  11.097606  7.381491  13.137697  2.979737  12.589072
# 5    0  2.337280e-01  14.751464  7.349398  12.811245  1.855072   9.542730
# 6    0           NaN   8.444397       NaN        NaN       NaN        NaN
# 7    0  4.168182e-01  16.027060  8.201295  14.150472  2.093457  11.028792
# 8    0  2.253813e-01  14.766660  7.582717  12.401712  0.995105   9.733040
# 9    0           NaN   5.195717       NaN        NaN       NaN        NaN
#
#          v45       v46 v47        v48       v49       v50       v51 v52  \
# 0   9.417172  0.100480   J  12.774528  7.509293  0.118847  8.590755   C
# 1        NaN       NaN   C        NaN       NaN  1.027070       NaN   A
# 2   7.908401  0.082194   I  12.770831  7.792207  0.840731  9.885153   A
# 3  12.850679  1.504218   I  16.791675  7.801759  0.946373  8.578365   A
# 4   9.237298  0.127957   I  10.579613  7.878104  1.493654  5.513188   H
# 5   9.521419  0.098018   G  13.928915  8.366801  0.491526  9.137001   D
# 6        NaN       NaN   J        NaN       NaN  3.119359       NaN   L
# 7   7.840153  1.446033   I  11.547765  8.868958  0.500330  4.479544   G
# 8   8.988426  0.213590   C  13.168317  8.275594  0.944905  8.678721   A
# 9        NaN       NaN   F        NaN       NaN  1.669723       NaN   B
#
#          v53       v54       v55  v56       v57           v58        v59  \
# 0  17.021277  0.044313  1.338291   AF  2.602230  2.919712e-01   9.038609
# 1        NaN       NaN       NaN   DI       NaN           NaN        NaN
# 2  15.000000  0.020126  0.779222   DO  5.454544 -8.476044e-07   9.452010
# 3  15.382717  1.351259  3.812951   CN  4.356514  1.953542e+01  10.425885
# 4  15.668791  0.063023  0.880361  NaN  5.259594  7.723043e-01  11.048157
# 5  16.626087  0.112979  2.449799   DP  4.056225  9.876538e-01  10.050132
# 6        NaN       NaN       NaN   BJ       NaN           NaN        NaN
# 7  15.675676  1.487041  1.464873   DO  4.105631  1.108582e+01  11.203995
# 8  16.000000  0.181417  0.934215   BW  3.604515  1.072115e+01  10.260224
# 9        NaN       NaN       NaN    U       NaN           NaN        NaN
#
#         v60        v61  v62       v63       v64        v65 v66        v67  \
# 0  0.817843  14.911512    1  0.091466  5.967949  15.611474   A   8.029739
# 1       NaN        NaN    1       NaN       NaN        NaN   C        NaN
# 2  2.857142  15.561143    1  0.083718  5.633655  15.778656   C   9.090908
# 3  1.128431  10.935236    1  1.809689  2.181748  12.366115   B   8.401279
# 4  2.462377  16.945301    2  0.123527  8.188559  17.490176   B   9.469527
# 5  1.398928  14.973973    1  0.105995  4.340699  15.035700   A   9.236948
# 6       NaN        NaN    3       NaN       NaN        NaN   A        NaN
# 7  1.863478  14.274988    1  1.576003  8.034798  17.462451   A  10.662681
# 8  0.742183  14.675999    1  0.310522  5.480912  16.842927   A   9.544570
# 9       NaN        NaN    1       NaN       NaN        NaN   C        NaN
#
#          v68        v69        v70 v71  v72       v73 v74 v75       v76  \
# 0  15.912409   8.571429  11.222210   F    1  1.929013   B   D  2.146860
# 1        NaN        NaN        NaN   F    5       NaN   B   D       NaN
# 2  13.200000   6.666666   7.860585   F    1  1.488096   B   D  1.910292
# 3  17.677120  13.195021  14.124303   F    1  3.905010   B   D  0.644581
# 4  18.695074   9.811320  13.146984   F    2  1.465039   B   D  3.127512
# 5  18.240740  10.608695  11.701400   F    1  2.324879   B   D  1.401582
# 6        NaN        NaN        NaN   F    3       NaN   B   D       NaN
# 7  17.985990  13.611112  11.604963   F    1  2.628504   B   D  3.094367
# 8  17.724359   8.247422  13.426219   F    2  3.245650   B   D  1.891708
# 9        NaN        NaN        NaN   F    1       NaN   B   D       NaN
#
#         v77        v78 v79       v80       v81       v82       v83       v84  \
# 0  6.171004  15.714287   Q  1.904761  8.918731  8.750729  2.453532  0.892192
# 1       NaN        NaN   E       NaN       NaN       NaN       NaN       NaN
# 2  5.714285  16.666667   C  1.428572  8.952301  8.744891  1.948051  0.779221
# 3  6.370902  11.203320   C  3.555555  6.284919  3.264427  3.237409  4.220623
# 4  7.799097  14.716980   C  1.032259  6.837319  8.715703  1.320542  0.541761
# 5  6.907630  12.347825   M  4.774194  9.900686  8.406304  2.851405  2.971887
# 6       NaN        NaN   H       NaN       NaN       NaN       NaN       NaN
# 7  8.310912  10.833334   C  1.600000  8.904157  3.389216  1.165920  1.315396
# 8  8.127676  14.639175   B  1.072555  7.270358  3.661191  1.658233  0.794084
# 9       NaN        NaN   K       NaN       NaN       NaN       NaN       NaN
#
#         v85       v86        v87       v88       v89       v90 v91       v92  \
# 0  1.860465  0.892193   7.904968  1.784387  0.105298  0.988980   B  0.658269
# 1       NaN       NaN        NaN       NaN       NaN       NaN   C       NaN
# 2  1.860465  0.779221   5.886226  5.714285  0.043851  0.918734   C  0.552642
# 3  6.000001  1.306954  13.037068  0.431654  2.035947  1.495102   B  0.775499
# 4  0.952380  0.863431  12.073390  2.234763  0.150041  0.993206   B  0.389974
# 5  2.149532  0.783132   6.692097  1.606426  0.053529  1.006321   C  0.529553
# 6       NaN       NaN        NaN       NaN       NaN       NaN   G       NaN
# 7  2.048417  1.689088   7.866165  3.567514  0.749803  0.763345   G  0.658457
# 8  3.744681  2.031920  10.226870  1.479175  0.165683  0.943545   G  0.930603
# 9       NaN       NaN        NaN       NaN       NaN       NaN   B       NaN
#
#         v93       v94       v95       v96        v97        v98       v99  \
# 0  4.929298  2.992365  0.759955  5.947955   4.999999  10.013503  0.817844
# 1       NaN       NaN       NaN       NaN        NaN        NaN       NaN
# 2  4.350983  3.163664  0.604966  6.233767  12.631578  10.214574  0.952380
# 3  3.176199  5.071340  1.020527  4.980016   8.603352   5.743589  0.688783
# 4  5.632135  3.885107  0.417548  6.941310   7.652733   8.589221  1.075998
# 5  4.549925  3.785681  0.645640  6.398928   6.440678   7.571328  1.055333
# 6       NaN       NaN       NaN       NaN        NaN        NaN       NaN
# 7  8.104410  3.694061  0.702215  7.802691   7.999999   6.351981  1.735592
# 8  5.321216  3.017868  1.003715  7.037758   4.905659   8.209414  0.884910
# 9       NaN       NaN       NaN       NaN        NaN        NaN       NaN
#
#         v100       v101      v102      v103      v104      v105       v106  \
# 0  19.708030   4.186787  1.873945  4.129022  1.701894  0.004535  11.688117
# 1        NaN        NaN       NaN       NaN       NaN       NaN        NaN
# 2  19.799999   6.535555  0.762963  4.917534  1.981859  0.002794  11.747048
# 3   0.116143   3.627655       NaN  7.486234  4.313037  1.048637   5.957084
# 4  19.227696   6.606787  1.493882  4.929004  1.906923  0.055134  14.666965
# 5  18.950617   5.467954  1.820259  5.440665  2.261760  0.027792   9.968654
# 6        NaN        NaN       NaN       NaN       NaN       NaN        NaN
# 7   7.950963  10.022851  2.668494  5.106525  2.987106  1.023943  13.349134
# 8   9.214744   8.412875  2.208578  4.126977  2.690052  0.146540  11.206439
# 9        NaN        NaN       NaN       NaN       NaN       NaN        NaN
#
#   v107      v108      v109 v110      v111 v112 v113       v114       v115  \
# 0    B  1.502480  2.121710    A  3.568773    U  NaN  12.246698  11.428572
# 1    D       NaN       NaN    B       NaN    E  NaN  16.284938        NaN
# 2    D  1.188768  2.088817    A  3.116883    Q   AJ  15.622710  13.333334
# 3    B  2.690866  6.211596    A  3.932854    F    G  13.701587   6.804980
# 4    B  2.467017  5.312500    A  1.828443    A    I  13.395401  10.188679
# 5    D  1.472781  1.365132    A  4.337350    I    G   9.275629   9.391304
# 6    C       NaN       NaN    A       NaN    L    G  15.866593        NaN
# 7    C  1.338413  2.385233    A  1.375186    I   AG   7.571114   6.388890
# 8    C  1.942253  3.646585    B  2.662515    C  NaN   9.529026  11.752577
# 9    B       NaN       NaN    A       NaN    U    M  17.353092        NaN
#
#        v116       v117       v118          v119      v120      v121  \
# 0  1.276596   4.777902   5.833334 -9.974950e-07  1.459854  3.267328
# 1       NaN        NaN        NaN           NaN       NaN       NaN
# 2  3.750001   4.740574  12.631580  4.910660e-08  0.600000  2.500001
# 3  1.901235  12.446092  10.726256  1.824479e+01  2.322881  4.149590
# 4  3.031846   7.637177   8.038585  6.626723e-01  0.852197  1.676217
# 5  1.982608   3.747666   7.231637  2.073860e-01  1.574074  3.408000
# 6       NaN        NaN        NaN           NaN       NaN       NaN
# 7  2.042042   7.854036   8.784314  1.273483e+00  1.628722  1.314607
# 8  0.920355  10.287678   5.754717  2.317138e+00  2.051282  2.003762
# 9       NaN        NaN        NaN           NaN       NaN       NaN
#
#         v122      v123          v124 v125      v126      v127      v128  v129  \
# 0   7.619048  1.815241  1.112270e-07   AF  1.292368  3.903345  1.485925     0
# 1        NaN       NaN           NaN    I       NaN       NaN       NaN     0
# 2   5.714286  1.970928  1.412265e-02   AV  1.128724  5.844156  1.475892     0
# 3   4.404040  8.163614  1.100329e+00    B  1.988688  1.558753  2.448814     0
# 4   6.580644  1.325654  2.584588e-01    A  1.863796  2.666478  2.374275     0
# 5   5.032257  2.551374 -9.391195e-07   BM  1.541607  3.463855  1.196959     0
# 6        NaN       NaN           NaN   CK       NaN       NaN       NaN     0
# 7   8.218182  2.011008  6.788057e-01   BJ  1.591433  2.541105  1.386445     0
# 8  10.977917  2.984337  4.996407e-03   BH  1.327866  3.999610  1.854306     1
# 9        NaN       NaN           NaN   AN       NaN       NaN       NaN     0
#
#        v130          v131
# 0  2.333334  1.428572e+00
# 1       NaN           NaN
# 2  1.263157 -6.380022e-07
# 3  5.385474  1.493777e+00
# 4  0.681672  2.264151e+00
# 5  2.598869  1.217392e+00
# 6       NaN           NaN
# 7  1.129412  3.055555e+00
# 8  1.830189  1.855670e+00
# 9       NaN           NaN

# %%
features_list = ['v50','v12','v21','v22',
                 'v114','v34','v10','v40','v14','v125',
                 'v112','v52']
df_test_slimmed = df_test[features_list]

# %%
for i in df_test_slimmed.columns:
    if df_test_slimmed[i].dtype == 'O':
        print 'Labels in column %s:' % i, len(np.unique(df_test_slimmed[i]))
        class_mapping = {label:idx for idx,label in enumerate(np.unique(df_test_slimmed[i]))}
        df_test_slimmed[i] = df_test_slimmed[i].map(class_mapping)
# Out:
# Labels in column v22: 18253
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Labels in column v125: 91
# Labels in column v112: 23
# Labels in column v52: 13

# %%
df_test_slimmed.head(10)
# Out:
#         v50       v12       v21    v22       v114       v34       v10  \
# 0  0.118847  6.961173  7.437806   3041  12.246698  5.228503  1.312911
# 1  1.027070  6.618289  5.895192   7095  16.284938  8.387431  1.291029
# 2  0.840731  6.894249  8.253452   8385  15.622710  7.958990  1.575492
# 3  0.946373  6.856236  5.539484   3541  13.701587  6.223849  1.575493
# 4  1.493654  6.273627  6.741530   4541  13.395401  5.476858  1.050328
# 5  0.491526  6.344974  7.210579  12479   9.275629  2.915391  0.656456
# 6  3.119359  6.443916  4.090771   4284  15.866593  7.809384  2.078774
# 7  0.500330  6.052550  7.930243   2751   7.571114  1.857987  0.262583
# 8  0.944905  9.540419  8.439870   6736   9.529026  5.816583  5.229759
# 9  1.669723  6.210270  6.985110  16608  17.353092  9.209334  1.050329
#
#          v40        v14  v125  v112  v52
# 0  11.754576  12.230137     7    21    3
# 1   6.737574  10.760796    73     5    1
# 2   7.701325  13.306189    23    17    1
# 3  10.444974  10.397026    28     6    1
# 4  11.097606  11.354501     1     1    8
# 5  14.751464  11.268329    41     9    4
# 6   8.444397   9.522445    66    12   12
# 7  16.027060  10.991098    38     9    7
# 8  14.766660  14.775679    36     3    1
# 9   5.195717  11.636386    15    21    2

# %%
X_test= df_test_slimmed[:]

# %%
X_test.shape
# Out:
# (114393, 12)

# %%
from sklearn.preprocessing import Imputer
imr = Imputer(missing_values='NaN', strategy='mean', axis=0)
imr.fit(X_test)
X_test = imr.transform(X_test)
